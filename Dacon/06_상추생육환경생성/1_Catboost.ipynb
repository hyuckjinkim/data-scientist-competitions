# %% [markdown]
# # Import

# %%
import random
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
import numpy as np
import os
import glob

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from tqdm.auto import tqdm

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
fp = fm.FontProperties(fname='/home/studio-lab-user/Dacon/tools/NanumFont/NanumGothic.ttf', size=10)
import seaborn as sns

import warnings
warnings.filterwarnings(action='ignore')

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print('device :',device)
# Out:
# device : cpu

# %% [markdown]
# <br></br>
#
# # Setting

# %% [markdown]
# <br>
#
# ## Hyperparameter Setting

# %%
CFG = {
    'EPOCHS':10,#1024,
    'PATIENCE':30,
    'LEARNING_RATE':0.05,
    'BATCH_SIZE':16,
    'SEED':42,
}

# %% [markdown]
# <br>
#
# ## Fixed RandomSeed

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything(CFG['SEED']) # Seed 고정

# %% [markdown]
# <br></br>
#
# # Data Pre-processing

# %%
all_input_list  = sorted(glob.glob('./data/train_input/*.csv'))
all_target_list = sorted(glob.glob('./data/train_target/*.csv'))
all_test_list   = sorted(glob.glob('./data/test_input/*.csv'))

# %%
import os
from sklearn.preprocessing import MinMaxScaler

class Preprocess:
    def __init__(self, input_paths, label_paths, test_paths):
        self.input_paths = input_paths
        self.label_paths = label_paths
        self.test_paths  = test_paths
        
        self.input, self.label, self.test = None, None, None
        
        self.X_train, self.X_valid = None, None
        self.y_train, self.y_valid = None, None
        self.X, self.y = None, None

        input_fn = []
        label_fn = []
        for input_path, label_path in zip(self.input_paths, self.label_paths):
            case_num = input_path.replace('./data/train_input/CASE_','').replace('.csv','')
            
            input_df = pd.read_csv(input_path)
            label_df = pd.read_csv(label_path)

            input_df = input_df.fillna(0)

            input_df['case_num'] = case_num
            label_df['case_num'] = case_num
            
            input_fn.append(input_df)
            label_fn.append(label_df)
        
        test_fn = []
        for test_path in self.test_paths:
            test_df = pd.read_csv(test_path)
            case_num = test_path.replace('./data/test_input/TEST_','').replace('.csv','')
            
            test_df['case_num'] = case_num
            
            test_fn.append(test_df)
            
        self.input = pd.concat(input_fn,axis=0).sort_values(['case_num','DAT','obs_time'])
        self.label = pd.concat(label_fn,axis=0)
        self.test  = pd.concat(test_fn ,axis=0)
        
    def _data_return(self):
        return self.input,self.label,self.test
    
    def _preprocess(self):
        self.input['time'] = [i+1 for i in range(28*24)]*self.input.case_num.nunique()
        self.test ['time'] = [i+1 for i in range(28*24)]*self.test .case_num.nunique()
        # input_df.groupby(['case_num'])['time'].max()
        
        # self.input.drop(columns=['DAT','obs_time'],inplace=True)
        # self.test .drop(columns=['DAT','obs_time'],inplace=True)
        
    # https://dacon.io/competitions/official/236033/talkboard/407304?page=1&dtype=recent
    def _scale_dataset(self):
        
        minmax_info = {
            'time':[0,28*24],
            '내부온도관측치':[4,40],
            '내부습도관측치':[0,100],
            'co2관측치':[0,1200],
            'ec관측치':[0,8],
            '시간당분무량':[0,3000],
            '일간누적분무량':[0,72000],
            '시간당백색광량':[0,120000],
            '일간누적백색광량':[0,2880000],
            '시간당적색광량':[0,120000],
            '일간누적적색광량':[0,2880000],
            '시간당청색광량':[0,120000],
            '일간누적청색광량':[0,2880000],
            '시간당총광량':[0,120000],
            '일간누적총광량':[0,2880000],
        }
        scale_feature = [feature for feature,(min_info,max_info) in minmax_info.items()]
        
        # for train dataset
        for col in scale_feature:
            min_info,max_info = minmax_info[col]
            self.input[col] = (self.input[col]-min_info) / (max_info-min_info)
            
        # for test dataset
        for col in scale_feature:
            min_info,max_info = minmax_info[col]
            self.test[col] = (self.test[col]-min_info) / (max_info-min_info)
        
    def _interaction_term(self):
        num_features = self.input.select_dtypes(exclude=[object]).columns
        num_features = list(set(num_features)-set(['DAT','obs_time']))
        for i in range(len(num_features)):
            for j in range(len(num_features)):
                if i>j:
                    self.input[f'{num_features[i]}*{num_features[j]}'] = self.input[num_features[i]]*self.input[num_features[j]]
                    self.test [f'{num_features[i]}*{num_features[j]}'] = self.test [num_features[i]]*self.test [num_features[j]]

    def _train_test_split(self, val_rate):
        val_size = int(self.input.DAT.nunique() * val_rate)

        tr_idx = self.input.DAT <  max(self.input.DAT)-val_size
        va_idx = self.input.DAT >= max(self.input.DAT)-val_size
        
        self.X_train = self.input[tr_idx]
        self.X_valid = self.input[va_idx]
        self.y_train = self.label[self.label.DAT.isin(self.X_train.DAT.unique()+1)]
        self.y_valid = self.label[self.label.DAT.isin(self.X_valid.DAT.unique()+1)]

        print(f'val_rate={val_rate}')
        print(f'train DAT : [{self.X_train.DAT.min()}~{self.X_train.DAT.max()}], validation DAT : [{self.X_valid.DAT.min()}~{self.X_valid.DAT.max()}]')
    
    def _return_train_range(self):
        return self.X_train.DAT.max()

    def _transform_dataset(self):
        self.y_train['predicted_weight_g'] = np.log(self.y_train['predicted_weight_g'])
        self.y_valid['predicted_weight_g'] = np.log(self.y_valid['predicted_weight_g'])
    
    def _save(self):
        self.X = pd.concat([self.X_train,self.X_valid],axis=0)
        self.y = pd.concat([self.y_train,self.y_valid],axis=0)
        
        mkdir_paths = ['./out/train_input','./out/train_target','./out/test_input']
        for path in mkdir_paths:
            if not os.path.exists(path):
                os.mkdir(path)
        
        print('Save Start ...')
        for case_num in self.X.case_num.unique():
            _X = self.X[self.X.case_num==case_num].drop(['case_num','obs_time'],axis=1)
            _y = self.y[self.y.case_num==case_num].drop(['case_num'],axis=1)
            
            _X.to_csv(f'./out/train_input/CASE_{case_num}.csv',index=False)
            _y.to_csv(f'./out/train_target/CASE_{case_num}.csv',index=False)
            
        for case_num in self.test.case_num.unique():
            _X = self.test[self.test.case_num==case_num].drop('case_num',axis=1)
            
            _X.to_csv(f'./out/test_input/TEST_{case_num}.csv',index=False)
        print('Save Done ...')

# %%
# val_rate = 0.05

# dataset = Preprocess(
#     input_paths = all_input_list,
#     label_paths = all_target_list,
#     test_paths = all_test_list,
# )

# # preprocessing + scaling + interaction term
# dataset._preprocess()
# dataset._scale_dataset()
# dataset._interaction_term()

# # train/validation split
# dataset._train_test_split(val_rate=val_rate)
# train_max_dat = dataset._return_train_range()

# # target transform
# dataset._transform_dataset()

# # save dataset
# dataset._save()

# %%
# from scipy.stats import pearsonr

# val_rate = 0.05

# dataset = Preprocess(
#     input_paths = all_input_list,
#     label_paths = all_target_list,
#     test_paths = all_test_list,
# )

# dataset._preprocess()
# dataset._scale_dataset()
# input_df, label_df = dataset._data_return()

# for case_num in tqdm(sorted(input_df.case_num.unique())):

#     input = input_df[input_df.case_num==case_num].drop('case_num',axis=1)
#     label = label_df[label_df.case_num==case_num].drop('case_num',axis=1)

#     fig = plt.figure(figsize=(20,15))
#     nrow = 3
#     ncol = 5

#     iter = 0
#     total = len(input.columns)-3
#     for col in input.columns:
#         if col not in ['time','DAT','obs_time']:
#             iter+=1

#             y1 = input[col]
#             #y1 = (y1-y1.min())/(y1.max()-y1.min())

#             y2 = label['predicted_weight_g']
#             y2 = (y2-y2.min())/(y2.max()-y2.min())

#             y3 = input.groupby('DAT')[col].mean().values

#             corr, pvalue = pearsonr(y2,y3)

#             fig.add_subplot(ncol,nrow,iter)
#             sns.scatterplot(x=input.time  ,y=y1)
#             sns.scatterplot(x=label.DAT*24,y=y2,color='red')
#             sns.lineplot   (x=label.DAT*24,y=y3,color='blue',linestyle='--',alpha=0.7)
#             plt.ylabel('')

#             plt.title(f'{col}(corr={corr:.3f}(pvalue={pvalue:.3f}))',fontproperties=fp)


#     plt.tight_layout()
#     plt.savefig(f'./fig/{case_num}.png',dpi=100)
#     plt.close()

# %% [markdown]
# <br>
#
# # Modeling

# %% [markdown]
# <br>
#
# ## 모델1

# %%
from scipy.stats import pearsonr

val_rate = 0.05

dataset = Preprocess(
    input_paths = all_input_list,
    label_paths = all_target_list,
    test_paths = all_test_list,
)

dataset._preprocess()
dataset._scale_dataset()
# dataset._interaction_term()

input_df, label_df, test_df = dataset._data_return()
input_df = input_df.drop(columns=['obs_time']).groupby(['case_num','DAT']).mean().reset_index()
test_df  = test_df .drop(columns=['obs_time']).groupby(['case_num','DAT']).mean().reset_index()

input_df = input_df.drop(columns=['case_num'])
test_df  = test_df .drop(columns=['case_num'])
label_df = label_df['predicted_weight_g']

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(input_df,label_df,test_size=0.05,random_state=42)
X_train.shape, X_valid.shape
# Out:
# ((548, 16), (236, 16))

# %%
from catboost import CatBoostRegressor
from sklearn.model_selection import KFold

tr_preds = []
va_preds = []
te_preds = []
kf = KFold(n_splits=5, shuffle=True, random_state=42)
for tr_idx,va_idx in tqdm(kf.split(X_train),total=5):
    X_tr, y_tr = X_train.iloc[tr_idx,:], y_train.iloc[tr_idx]
    X_va, y_va = X_train.iloc[va_idx,:], y_train.iloc[va_idx]

    model = CatBoostRegressor(iterations=5000,metric_period=1000,verbose=1,random_state=42)
    model.fit(X_tr,y_tr,eval_set=[(X_va,y_va)])

    tr_pred = model.predict(X_train)
    va_pred = model.predict(X_valid)
    te_pred = model.predict(test_df)
    
    tr_preds.append(tr_pred)
    va_preds.append(va_pred)
    te_preds.append(te_pred)

# %%
from sklearn.metrics import mean_squared_error

tr_pred = np.mean(tr_preds,axis=0)
va_pred = np.mean(va_preds,axis=0)
te_pred = np.mean(te_preds,axis=0)

tr_score = np.sqrt(mean_squared_error(y_pred=tr_pred,y_true=y_train))
va_score = np.sqrt(mean_squared_error(y_pred=va_pred,y_true=y_valid))
print(tr_score,va_score)

# %%
i = 0
for case_num in ['01','02','03','04','05']:
    test_case_df = pd.read_csv(f'./data/test_target/TEST_{case_num}.csv')
    test_case_df['predicted_weight_g'] = te_pred[(i*28):(i*28+28)]
    test_case_df.to_csv(f'./data/test_target/TEST_{case_num}.csv',index=False)
    i+=1

# %%
import zipfile

test_target_list = sorted(glob.glob('/home/studio-lab-user/Dacon/6_상추생육환경생성/data/test_target/*.csv'))

os.chdir("./data/test_target/")
submission = zipfile.ZipFile("../submission.zip", 'w')
for path in test_target_list:
    path = path.split('/')[-1]
    submission.write(path)
submission.close()

# %% [markdown]
# <br>
#
# ## 모델2

# %%
from scipy.stats import pearsonr

val_rate = 0.05

dataset = Preprocess(
    input_paths = all_input_list,
    label_paths = all_target_list,
    test_paths = all_test_list,
)

dataset._preprocess()
dataset._scale_dataset()
dataset._interaction_term()

input_df, label_df, test_df = dataset._data_return()
input_df = input_df.drop(columns=['obs_time']).groupby(['case_num','DAT']).mean().reset_index()
test_df  = test_df .drop(columns=['obs_time']).groupby(['case_num','DAT']).mean().reset_index()

input_df = input_df.drop(columns=['case_num'])
test_df  = test_df .drop(columns=['case_num'])
label_df = label_df['predicted_weight_g']

# %%
from catboost import CatBoostRegressor
from sklearn.model_selection import KFold

tr_preds = []
va_preds = []
te_preds = []
kf = KFold(n_splits=5, shuffle=True, random_state=42)
for tr_idx,va_idx in tqdm(kf.split(input_df),total=5):
    X_train, y_train = input_df.iloc[tr_idx,:], label_df.iloc[tr_idx]
    X_valid, y_valid = input_df.iloc[va_idx,:], label_df.iloc[va_idx]

    model = CatBoostRegressor(iterations=100,metric_period=1,verbose=1,random_state=42)
    model.fit(
        X_train,
        y_train,
        eval_set=[(X_valid,y_valid)],
        use_best_model=True,
    )

    tr_pred = model.predict(X_train)
    va_pred = model.predict(X_valid)
    te_pred = model.predict(test_df)
    
    tr_preds.append(tr_pred)
    va_preds.append(va_pred)
    te_preds.append(te_pred)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Learning rate set to 0.192782
# 0:	learn: 36.3305174	test: 38.0455554	best: 38.0455554 (0)	total: 64ms	remaining: 6.34s
# 1:	learn: 31.8288525	test: 33.5061117	best: 33.5061117 (1)	total: 89.2ms	remaining: 4.37s
# 2:	learn: 28.1843258	test: 29.8735731	best: 29.8735731 (2)	total: 109ms	remaining: 3.54s
# 3:	learn: 25.0522341	test: 27.1465967	best: 27.1465967 (3)	total: 137ms	remaining: 3.29s
# 4:	learn: 22.2488264	test: 24.6233582	best: 24.6233582 (4)	total: 156ms	remaining: 2.97s
# 5:	learn: 20.0029828	test: 22.6876843	best: 22.6876843 (5)	total: 179ms	remaining: 2.8s
# 6:	learn: 18.1497606	test: 20.6771933	best: 20.6771933 (6)	total: 207ms	remaining: 2.75s
# 7:	learn: 16.3038726	test: 19.0371491	best: 19.0371491 (7)	total: 231ms	remaining: 2.66s
# 8:	learn: 14.8604544	test: 17.8324236	best: 17.8324236 (8)	total: 250ms	remaining: 2.52s
# 9:	learn: 13.5972639	test: 16.6960906	best: 16.6960906 (9)	total: 272ms	remaining: 2.44s
# 10:	learn: 12.5417277	test: 15.8976317	best: 15.8976317 (10)	total: 299ms	remaining: 2.42s
# 11:	learn: 11.6493003	test: 15.3580318	best: 15.3580318 (11)	total: 324ms	remaining: 2.38s
# 12:	learn: 10.8134716	test: 14.6697440	best: 14.6697440 (12)	total: 349ms	remaining: 2.33s
# 13:	learn: 10.0805477	test: 14.2365966	best: 14.2365966 (13)	total: 376ms	remaining: 2.31s
# 14:	learn: 9.5639539	test: 13.7683259	best: 13.7683259 (14)	total: 400ms	remaining: 2.27s
# 15:	learn: 9.1402648	test: 13.6582948	best: 13.6582948 (15)	total: 427ms	remaining: 2.24s
# 16:	learn: 8.6936576	test: 13.4100320	best: 13.4100320 (16)	total: 451ms	remaining: 2.2s
# 17:	learn: 8.3040519	test: 13.1671201	best: 13.1671201 (17)	total: 481ms	remaining: 2.19s
# 18:	learn: 8.0957894	test: 13.0129453	best: 13.0129453 (18)	total: 509ms	remaining: 2.17s
# 19:	learn: 7.8753706	test: 12.8721485	best: 12.8721485 (19)	total: 534ms	remaining: 2.14s
# 20:	learn: 7.6674345	test: 12.7769785	best: 12.7769785 (20)	total: 558ms	remaining: 2.1s
# 21:	learn: 7.4123766	test: 12.5768009	best: 12.5768009 (21)	total: 582ms	remaining: 2.06s
# 22:	learn: 7.1948700	test: 12.3690218	best: 12.3690218 (22)	total: 599ms	remaining: 2.01s
# 23:	learn: 6.9482997	test: 12.1103959	best: 12.1103959 (23)	total: 616ms	remaining: 1.95s
# 24:	learn: 6.7556458	test: 11.8790632	best: 11.8790632 (24)	total: 634ms	remaining: 1.9s
# 25:	learn: 6.6136384	test: 11.8947258	best: 11.8790632 (24)	total: 652ms	remaining: 1.86s
# 26:	learn: 6.3664937	test: 11.8257728	best: 11.8257728 (26)	total: 670ms	remaining: 1.81s
# 27:	learn: 6.2435311	test: 11.7141381	best: 11.7141381 (27)	total: 686ms	remaining: 1.76s
# 28:	learn: 6.1552398	test: 11.6934311	best: 11.6934311 (28)	total: 713ms	remaining: 1.74s
# 29:	learn: 6.1012504	test: 11.6739665	best: 11.6739665 (29)	total: 728ms	remaining: 1.7s
# 30:	learn: 5.9530372	test: 11.6311698	best: 11.6311698 (30)	total: 744ms	remaining: 1.66s
# 31:	learn: 5.7765422	test: 11.4472602	best: 11.4472602 (31)	total: 760ms	remaining: 1.61s
# 32:	learn: 5.6704158	test: 11.3650927	best: 11.3650927 (32)	total: 777ms	remaining: 1.58s
# 33:	learn: 5.5870170	test: 11.3212280	best: 11.3212280 (33)	total: 797ms	remaining: 1.55s
# 34:	learn: 5.4316164	test: 11.2156351	best: 11.2156351 (34)	total: 827ms	remaining: 1.54s
# 35:	learn: 5.3603690	test: 11.1952272	best: 11.1952272 (35)	total: 847ms	remaining: 1.51s
# 36:	learn: 5.2688040	test: 11.1221437	best: 11.1221437 (36)	total: 866ms	remaining: 1.47s
# 37:	learn: 5.1702283	test: 11.0669333	best: 11.0669333 (37)	total: 891ms	remaining: 1.45s
# 38:	learn: 5.1392714	test: 11.0129089	best: 11.0129089 (38)	total: 916ms	remaining: 1.43s
# 39:	learn: 5.0201883	test: 10.9369594	best: 10.9369594 (39)	total: 945ms	remaining: 1.42s
# 40:	learn: 4.9442957	test: 10.8478202	best: 10.8478202 (40)	total: 968ms	remaining: 1.39s
# 41:	learn: 4.9205523	test: 10.8281550	best: 10.8281550 (41)	total: 993ms	remaining: 1.37s
# 42:	learn: 4.7957969	test: 10.7343170	best: 10.7343170 (42)	total: 1.02s	remaining: 1.35s
# 43:	learn: 4.6776714	test: 10.6498805	best: 10.6498805 (43)	total: 1.04s	remaining: 1.33s
# 44:	learn: 4.5801521	test: 10.5951339	best: 10.5951339 (44)	total: 1.08s	remaining: 1.32s
# 45:	learn: 4.5198547	test: 10.5717420	best: 10.5717420 (45)	total: 1.1s	remaining: 1.29s
# 46:	learn: 4.4990334	test: 10.5464961	best: 10.5464961 (46)	total: 1.13s	remaining: 1.27s
# 47:	learn: 4.4770479	test: 10.5098641	best: 10.5098641 (47)	total: 1.15s	remaining: 1.24s
# 48:	learn: 4.3913168	test: 10.4763509	best: 10.4763509 (48)	total: 1.17s	remaining: 1.22s
# 49:	learn: 4.3106150	test: 10.4435694	best: 10.4435694 (49)	total: 1.19s	remaining: 1.19s
# 50:	learn: 4.2514407	test: 10.3542795	best: 10.3542795 (50)	total: 1.21s	remaining: 1.16s
# 51:	learn: 4.1777072	test: 10.3536866	best: 10.3536866 (51)	total: 1.24s	remaining: 1.14s
# 52:	learn: 4.0804956	test: 10.2620973	best: 10.2620973 (52)	total: 1.26s	remaining: 1.12s
# 53:	learn: 4.0609449	test: 10.1903908	best: 10.1903908 (53)	total: 1.28s	remaining: 1.09s
# 54:	learn: 3.9679649	test: 10.1397492	best: 10.1397492 (54)	total: 1.3s	remaining: 1.06s
# 55:	learn: 3.9034849	test: 10.1616178	best: 10.1397492 (54)	total: 1.32s	remaining: 1.04s
# 56:	learn: 3.8345719	test: 10.0929175	best: 10.0929175 (56)	total: 1.34s	remaining: 1.01s
# 57:	learn: 3.7771896	test: 10.0655481	best: 10.0655481 (57)	total: 1.36s	remaining: 983ms
# 58:	learn: 3.7066334	test: 10.0374626	best: 10.0374626 (58)	total: 1.38s	remaining: 957ms
# 59:	learn: 3.6615945	test: 10.0076298	best: 10.0076298 (59)	total: 1.4s	remaining: 931ms
# 60:	learn: 3.6096142	test: 9.9629861	best: 9.9629861 (60)	total: 1.41s	remaining: 903ms
# 61:	learn: 3.5038568	test: 9.9496302	best: 9.9496302 (61)	total: 1.43s	remaining: 878ms
# 62:	learn: 3.4600249	test: 9.9372300	best: 9.9372300 (62)	total: 1.46s	remaining: 855ms
# 63:	learn: 3.4072869	test: 9.9106550	best: 9.9106550 (63)	total: 1.48s	remaining: 834ms
# 64:	learn: 3.3543321	test: 9.8565647	best: 9.8565647 (64)	total: 1.5s	remaining: 810ms
# 65:	learn: 3.3063265	test: 9.8188519	best: 9.8188519 (65)	total: 1.53s	remaining: 788ms
# 66:	learn: 3.2951157	test: 9.8202781	best: 9.8188519 (65)	total: 1.55s	remaining: 765ms
# 67:	learn: 3.2391688	test: 9.8071604	best: 9.8071604 (67)	total: 1.57s	remaining: 739ms
# 68:	learn: 3.2079591	test: 9.8156819	best: 9.8071604 (67)	total: 1.59s	remaining: 713ms
# 69:	learn: 3.1516561	test: 9.7797756	best: 9.7797756 (69)	total: 1.61s	remaining: 692ms
# 70:	learn: 3.1203404	test: 9.7722278	best: 9.7722278 (70)	total: 1.64s	remaining: 671ms
# 71:	learn: 3.0817708	test: 9.7885277	best: 9.7722278 (70)	total: 1.66s	remaining: 647ms
# 72:	learn: 3.0423418	test: 9.7642141	best: 9.7642141 (72)	total: 1.69s	remaining: 625ms
# 73:	learn: 3.0290512	test: 9.7613899	best: 9.7613899 (73)	total: 1.71s	remaining: 602ms
# 74:	learn: 3.0168847	test: 9.7580058	best: 9.7580058 (74)	total: 1.74s	remaining: 579ms
# 75:	learn: 2.9219111	test: 9.7265874	best: 9.7265874 (75)	total: 1.76s	remaining: 558ms
# 76:	learn: 2.9122323	test: 9.7246321	best: 9.7246321 (76)	total: 1.79s	remaining: 534ms
# 77:	learn: 2.8596021	test: 9.6987067	best: 9.6987067 (77)	total: 1.82s	remaining: 513ms
# 78:	learn: 2.8017206	test: 9.6463610	best: 9.6463610 (78)	total: 1.84s	remaining: 488ms
# 79:	learn: 2.7596139	test: 9.6309222	best: 9.6309222 (79)	total: 1.86s	remaining: 465ms
# 80:	learn: 2.7521688	test: 9.6088552	best: 9.6088552 (80)	total: 1.89s	remaining: 442ms
# 81:	learn: 2.7461274	test: 9.6076913	best: 9.6076913 (81)	total: 1.91s	remaining: 418ms
# 82:	learn: 2.7135546	test: 9.5915655	best: 9.5915655 (82)	total: 1.94s	remaining: 397ms
# 83:	learn: 2.7053822	test: 9.5691061	best: 9.5691061 (83)	total: 1.96s	remaining: 373ms
# 84:	learn: 2.6924482	test: 9.5585022	best: 9.5585022 (84)	total: 1.99s	remaining: 351ms
# 85:	learn: 2.6864137	test: 9.5608228	best: 9.5585022 (84)	total: 2.02s	remaining: 328ms
# 86:	learn: 2.6504677	test: 9.5363427	best: 9.5363427 (86)	total: 2.04s	remaining: 304ms
# 87:	learn: 2.6246126	test: 9.5238108	best: 9.5238108 (87)	total: 2.07s	remaining: 282ms
# 88:	learn: 2.5827321	test: 9.5201873	best: 9.5201873 (88)	total: 2.09s	remaining: 258ms
# 89:	learn: 2.5609397	test: 9.5280984	best: 9.5201873 (88)	total: 2.1s	remaining: 234ms
# 90:	learn: 2.5210495	test: 9.4984122	best: 9.4984122 (90)	total: 2.13s	remaining: 210ms
# 91:	learn: 2.5142573	test: 9.4913306	best: 9.4913306 (91)	total: 2.16s	remaining: 188ms
# 92:	learn: 2.5094097	test: 9.4934619	best: 9.4913306 (91)	total: 2.18s	remaining: 164ms
# 93:	learn: 2.4816838	test: 9.4962408	best: 9.4913306 (91)	total: 2.21s	remaining: 141ms
# 94:	learn: 2.4754824	test: 9.4830578	best: 9.4830578 (94)	total: 2.24s	remaining: 118ms
# 95:	learn: 2.4261431	test: 9.4527960	best: 9.4527960 (95)	total: 2.27s	remaining: 94.6ms
# 96:	learn: 2.3905988	test: 9.4475932	best: 9.4475932 (96)	total: 2.3s	remaining: 71ms
# 97:	learn: 2.3611995	test: 9.4527293	best: 9.4475932 (96)	total: 2.31s	remaining: 47.3ms
# 98:	learn: 2.3551275	test: 9.4500725	best: 9.4475932 (96)	total: 2.34s	remaining: 23.6ms
# 99:	learn: 2.3513240	test: 9.4412795	best: 9.4412795 (99)	total: 2.37s	remaining: 0us
#
# bestTest = 9.441279503
# bestIteration = 99
#
# Learning rate set to 0.192782
# 0:	learn: 35.6705168	test: 39.8130731	best: 39.8130731 (0)	total: 29.2ms	remaining: 2.89s
# 1:	learn: 31.6162408	test: 35.3606225	best: 35.3606225 (1)	total: 52.3ms	remaining: 2.56s
# 2:	learn: 27.8544986	test: 31.5077699	best: 31.5077699 (2)	total: 75.4ms	remaining: 2.44s
# 3:	learn: 24.6464005	test: 28.1942732	best: 28.1942732 (3)	total: 96.1ms	remaining: 2.31s
# 4:	learn: 21.7865918	test: 25.5014971	best: 25.5014971 (4)	total: 116ms	remaining: 2.21s
# 5:	learn: 19.7028511	test: 23.2778542	best: 23.2778542 (5)	total: 138ms	remaining: 2.16s
# 6:	learn: 17.9568712	test: 21.3819113	best: 21.3819113 (6)	total: 161ms	remaining: 2.14s
# 7:	learn: 16.1393772	test: 19.6350422	best: 19.6350422 (7)	total: 178ms	remaining: 2.05s
# 8:	learn: 14.8457097	test: 18.4866320	best: 18.4866320 (8)	total: 200ms	remaining: 2.02s
# 9:	learn: 13.6156484	test: 17.1591347	best: 17.1591347 (9)	total: 225ms	remaining: 2.03s
# 10:	learn: 12.6442999	test: 16.1927142	best: 16.1927142 (10)	total: 248ms	remaining: 2.01s
# 11:	learn: 11.6974275	test: 15.2542734	best: 15.2542734 (11)	total: 267ms	remaining: 1.96s
# 12:	learn: 10.8758271	test: 14.1923236	best: 14.1923236 (12)	total: 283ms	remaining: 1.89s
# 13:	learn: 10.2462442	test: 13.7199420	best: 13.7199420 (13)	total: 301ms	remaining: 1.85s
# 14:	learn: 9.6930031	test: 13.1732646	best: 13.1732646 (14)	total: 330ms	remaining: 1.87s
# 15:	learn: 9.2391692	test: 12.6707210	best: 12.6707210 (15)	total: 349ms	remaining: 1.83s
# 16:	learn: 8.7476722	test: 12.1328696	best: 12.1328696 (16)	total: 366ms	remaining: 1.78s
# 17:	learn: 8.4810681	test: 11.8392450	best: 11.8392450 (17)	total: 387ms	remaining: 1.76s
# 18:	learn: 8.2316546	test: 11.7359917	best: 11.7359917 (18)	total: 412ms	remaining: 1.75s
# 19:	learn: 7.9174458	test: 11.3862302	best: 11.3862302 (19)	total: 429ms	remaining: 1.72s
# 20:	learn: 7.7234995	test: 11.2749426	best: 11.2749426 (20)	total: 446ms	remaining: 1.68s
# 21:	learn: 7.4401306	test: 10.9052820	best: 10.9052820 (21)	total: 472ms	remaining: 1.67s
# 22:	learn: 7.2273730	test: 10.6509688	best: 10.6509688 (22)	total: 499ms	remaining: 1.67s
# 23:	learn: 7.0291998	test: 10.3777821	best: 10.3777821 (23)	total: 520ms	remaining: 1.65s
# 24:	learn: 6.9152940	test: 10.2164364	best: 10.2164364 (24)	total: 539ms	remaining: 1.61s
# 25:	learn: 6.7147372	test: 10.1137397	best: 10.1137397 (25)	total: 566ms	remaining: 1.61s
# 26:	learn: 6.5952568	test: 9.9731007	best: 9.9731007 (26)	total: 590ms	remaining: 1.6s
# 27:	learn: 6.3866234	test: 9.7703555	best: 9.7703555 (27)	total: 615ms	remaining: 1.58s
# 28:	learn: 6.2927780	test: 9.5883491	best: 9.5883491 (28)	total: 635ms	remaining: 1.55s
# 29:	learn: 6.2291415	test: 9.5698679	best: 9.5698679 (29)	total: 655ms	remaining: 1.53s
# 30:	learn: 6.1752763	test: 9.5205695	best: 9.5205695 (30)	total: 672ms	remaining: 1.5s
# 31:	learn: 6.0131058	test: 9.3822321	best: 9.3822321 (31)	total: 691ms	remaining: 1.47s
# 32:	learn: 5.9662923	test: 9.3763625	best: 9.3763625 (32)	total: 711ms	remaining: 1.44s
# 33:	learn: 5.9359407	test: 9.3840907	best: 9.3763625 (32)	total: 743ms	remaining: 1.44s
# 34:	learn: 5.8582845	test: 9.2782471	best: 9.2782471 (34)	total: 768ms	remaining: 1.43s
# 35:	learn: 5.7082129	test: 9.0984084	best: 9.0984084 (35)	total: 796ms	remaining: 1.41s
# 36:	learn: 5.5926812	test: 9.0442573	best: 9.0442573 (36)	total: 826ms	remaining: 1.41s
# 37:	learn: 5.5099626	test: 8.9540831	best: 8.9540831 (37)	total: 843ms	remaining: 1.38s
# 38:	learn: 5.4231083	test: 8.8590004	best: 8.8590004 (38)	total: 877ms	remaining: 1.37s
# 39:	learn: 5.3759618	test: 8.8438745	best: 8.8438745 (39)	total: 897ms	remaining: 1.34s
# 40:	learn: 5.2510827	test: 8.7444343	best: 8.7444343 (40)	total: 924ms	remaining: 1.33s
# 41:	learn: 5.1557197	test: 8.7359997	best: 8.7359997 (41)	total: 950ms	remaining: 1.31s
# 42:	learn: 5.0729376	test: 8.6622436	best: 8.6622436 (42)	total: 975ms	remaining: 1.29s
# 43:	learn: 4.9338829	test: 8.5095278	best: 8.5095278 (43)	total: 1s	remaining: 1.27s
# 44:	learn: 4.9190059	test: 8.4977799	best: 8.4977799 (44)	total: 1.02s	remaining: 1.24s
# 45:	learn: 4.7959050	test: 8.3891495	best: 8.3891495 (45)	total: 1.03s	remaining: 1.21s
# 46:	learn: 4.7719923	test: 8.4125524	best: 8.3891495 (45)	total: 1.06s	remaining: 1.19s
# 47:	learn: 4.7180490	test: 8.4095795	best: 8.3891495 (45)	total: 1.09s	remaining: 1.18s
# 48:	learn: 4.6052486	test: 8.3397590	best: 8.3397590 (48)	total: 1.11s	remaining: 1.15s
# 49:	learn: 4.5923253	test: 8.3263490	best: 8.3263490 (49)	total: 1.13s	remaining: 1.13s
# 50:	learn: 4.4469007	test: 8.2329650	best: 8.2329650 (50)	total: 1.15s	remaining: 1.11s
# 51:	learn: 4.3933803	test: 8.2364959	best: 8.2329650 (50)	total: 1.18s	remaining: 1.08s
# 52:	learn: 4.3242119	test: 8.2050109	best: 8.2050109 (52)	total: 1.2s	remaining: 1.06s
# 53:	learn: 4.1887779	test: 8.1422024	best: 8.1422024 (53)	total: 1.23s	remaining: 1.04s
# 54:	learn: 4.0791224	test: 8.0934346	best: 8.0934346 (54)	total: 1.25s	remaining: 1.02s
# 55:	learn: 3.9654141	test: 7.9838381	best: 7.9838381 (55)	total: 1.28s	remaining: 1.01s
# 56:	learn: 3.9107353	test: 7.8863471	best: 7.8863471 (56)	total: 1.3s	remaining: 980ms
# 57:	learn: 3.8440059	test: 7.8233434	best: 7.8233434 (57)	total: 1.32s	remaining: 956ms
# 58:	learn: 3.7972127	test: 7.7666967	best: 7.7666967 (58)	total: 1.34s	remaining: 931ms
# 59:	learn: 3.7821524	test: 7.7500416	best: 7.7500416 (59)	total: 1.36s	remaining: 908ms
# 60:	learn: 3.6966421	test: 7.7306550	best: 7.7306550 (60)	total: 1.38s	remaining: 882ms
# 61:	learn: 3.6206244	test: 7.6927846	best: 7.6927846 (61)	total: 1.4s	remaining: 855ms
# 62:	learn: 3.6111175	test: 7.6808841	best: 7.6808841 (62)	total: 1.41s	remaining: 829ms
# 63:	learn: 3.5789069	test: 7.6865515	best: 7.6808841 (62)	total: 1.43s	remaining: 805ms
# 64:	learn: 3.5273699	test: 7.6816927	best: 7.6808841 (62)	total: 1.46s	remaining: 787ms
# 65:	learn: 3.4276670	test: 7.6197979	best: 7.6197979 (65)	total: 1.49s	remaining: 766ms
# 66:	learn: 3.4165669	test: 7.6113048	best: 7.6113048 (66)	total: 1.51s	remaining: 745ms
# 67:	learn: 3.3455399	test: 7.5534803	best: 7.5534803 (67)	total: 1.53s	remaining: 723ms
# 68:	learn: 3.2740780	test: 7.5135955	best: 7.5135955 (68)	total: 1.55s	remaining: 698ms
# 69:	learn: 3.2494320	test: 7.4989005	best: 7.4989005 (69)	total: 1.57s	remaining: 675ms
# 70:	learn: 3.1962441	test: 7.4966765	best: 7.4966765 (70)	total: 1.6s	remaining: 655ms
# 71:	learn: 3.1617766	test: 7.4902600	best: 7.4902600 (71)	total: 1.63s	remaining: 632ms
# 72:	learn: 3.1207768	test: 7.4766120	best: 7.4766120 (72)	total: 1.65s	remaining: 610ms
# 73:	learn: 3.0738249	test: 7.4734156	best: 7.4734156 (73)	total: 1.68s	remaining: 589ms
# 74:	learn: 3.0072580	test: 7.4546008	best: 7.4546008 (74)	total: 1.7s	remaining: 566ms
# 75:	learn: 2.9803005	test: 7.4411181	best: 7.4411181 (75)	total: 1.72s	remaining: 543ms
# 76:	learn: 2.9169552	test: 7.4020490	best: 7.4020490 (76)	total: 1.74s	remaining: 518ms
# 77:	learn: 2.8956058	test: 7.4151788	best: 7.4020490 (76)	total: 1.75s	remaining: 495ms
# 78:	learn: 2.8770902	test: 7.3974136	best: 7.3974136 (78)	total: 1.77s	remaining: 472ms
# 79:	learn: 2.8388729	test: 7.3769862	best: 7.3769862 (79)	total: 1.79s	remaining: 448ms
# 80:	learn: 2.8141322	test: 7.3527330	best: 7.3527330 (80)	total: 1.81s	remaining: 424ms
# 81:	learn: 2.7968493	test: 7.3426176	best: 7.3426176 (81)	total: 1.84s	remaining: 404ms
# 82:	learn: 2.7439645	test: 7.2796279	best: 7.2796279 (82)	total: 1.86s	remaining: 380ms
# 83:	learn: 2.7391512	test: 7.2776241	best: 7.2776241 (83)	total: 1.88s	remaining: 358ms
# 84:	learn: 2.7053667	test: 7.2505977	best: 7.2505977 (84)	total: 1.9s	remaining: 335ms
# 85:	learn: 2.6906257	test: 7.2383089	best: 7.2383089 (85)	total: 1.91s	remaining: 312ms
# 86:	learn: 2.6745445	test: 7.2106824	best: 7.2106824 (86)	total: 1.93s	remaining: 289ms
# 87:	learn: 2.6239340	test: 7.1628017	best: 7.1628017 (87)	total: 1.95s	remaining: 266ms
# 88:	learn: 2.5809092	test: 7.1491463	best: 7.1491463 (88)	total: 1.98s	remaining: 244ms
# 89:	learn: 2.5593815	test: 7.1510791	best: 7.1491463 (88)	total: 1.99s	remaining: 222ms
# 90:	learn: 2.5441149	test: 7.1516457	best: 7.1491463 (88)	total: 2.01s	remaining: 199ms
# 91:	learn: 2.4957321	test: 7.1286858	best: 7.1286858 (91)	total: 2.03s	remaining: 177ms
# 92:	learn: 2.4520520	test: 7.1058038	best: 7.1058038 (92)	total: 2.05s	remaining: 154ms
# 93:	learn: 2.4090712	test: 7.0870271	best: 7.0870271 (93)	total: 2.08s	remaining: 133ms
# 94:	learn: 2.3868740	test: 7.0779779	best: 7.0779779 (94)	total: 2.1s	remaining: 111ms
# 95:	learn: 2.3601629	test: 7.0511650	best: 7.0511650 (95)	total: 2.12s	remaining: 88.3ms
# 96:	learn: 2.3215493	test: 7.0408303	best: 7.0408303 (96)	total: 2.16s	remaining: 66.7ms
# 97:	learn: 2.3075932	test: 7.0357045	best: 7.0357045 (97)	total: 2.18s	remaining: 44.4ms
# 98:	learn: 2.2894587	test: 7.0297646	best: 7.0297646 (98)	total: 2.2s	remaining: 22.3ms
# 99:	learn: 2.2755803	test: 6.9878347	best: 6.9878347 (99)	total: 2.22s	remaining: 0us
#
# bestTest = 6.987834692
# bestIteration = 99
#
# Learning rate set to 0.192782
# 0:	learn: 36.8450889	test: 37.3743194	best: 37.3743194 (0)	total: 36.8ms	remaining: 3.64s
# 1:	learn: 32.0369916	test: 32.9325656	best: 32.9325656 (1)	total: 56ms	remaining: 2.75s
# 2:	learn: 28.1775709	test: 28.8594203	best: 28.8594203 (2)	total: 80.8ms	remaining: 2.61s
# 3:	learn: 24.9575784	test: 25.4213709	best: 25.4213709 (3)	total: 99.1ms	remaining: 2.38s
# 4:	learn: 22.1562532	test: 23.0360351	best: 23.0360351 (4)	total: 133ms	remaining: 2.53s
# 5:	learn: 20.1039741	test: 21.3845234	best: 21.3845234 (5)	total: 165ms	remaining: 2.59s
# 6:	learn: 18.1186226	test: 19.3492100	best: 19.3492100 (6)	total: 197ms	remaining: 2.61s
# 7:	learn: 16.3604577	test: 17.5763248	best: 17.5763248 (7)	total: 218ms	remaining: 2.51s
# 8:	learn: 15.0024092	test: 16.5106140	best: 16.5106140 (8)	total: 252ms	remaining: 2.55s
# 9:	learn: 13.5615118	test: 15.2140062	best: 15.2140062 (9)	total: 276ms	remaining: 2.48s
# 10:	learn: 12.3790452	test: 14.2452696	best: 14.2452696 (10)	total: 316ms	remaining: 2.56s
# 11:	learn: 11.4420897	test: 13.3409573	best: 13.3409573 (11)	total: 354ms	remaining: 2.59s
# 12:	learn: 10.6172752	test: 12.8023380	best: 12.8023380 (12)	total: 373ms	remaining: 2.49s
# 13:	learn: 9.8690843	test: 12.2085928	best: 12.2085928 (13)	total: 390ms	remaining: 2.39s
# 14:	learn: 9.2724598	test: 11.7031184	best: 11.7031184 (14)	total: 408ms	remaining: 2.31s
# 15:	learn: 8.7626764	test: 11.3667953	best: 11.3667953 (15)	total: 427ms	remaining: 2.24s
# 16:	learn: 8.3918917	test: 11.1438382	best: 11.1438382 (16)	total: 445ms	remaining: 2.17s
# 17:	learn: 7.9369277	test: 10.8472050	best: 10.8472050 (17)	total: 462ms	remaining: 2.11s
# 18:	learn: 7.6761066	test: 10.6543611	best: 10.6543611 (18)	total: 480ms	remaining: 2.05s
# 19:	learn: 7.3718681	test: 10.4960138	best: 10.4960138 (19)	total: 497ms	remaining: 1.99s
# 20:	learn: 7.1688242	test: 10.2780506	best: 10.2780506 (20)	total: 515ms	remaining: 1.94s
# 21:	learn: 6.9247144	test: 10.1500738	best: 10.1500738 (21)	total: 533ms	remaining: 1.89s
# 22:	learn: 6.7739919	test: 10.0773577	best: 10.0773577 (22)	total: 551ms	remaining: 1.84s
# 23:	learn: 6.5258037	test: 9.8905987	best: 9.8905987 (23)	total: 569ms	remaining: 1.8s
# 24:	learn: 6.3931680	test: 9.7454633	best: 9.7454633 (24)	total: 586ms	remaining: 1.76s
# 25:	learn: 6.2713610	test: 9.6180118	best: 9.6180118 (25)	total: 602ms	remaining: 1.71s
# 26:	learn: 6.1276247	test: 9.5364570	best: 9.5364570 (26)	total: 619ms	remaining: 1.67s
# 27:	learn: 5.9884921	test: 9.4534054	best: 9.4534054 (27)	total: 638ms	remaining: 1.64s
# 28:	learn: 5.9361558	test: 9.3675751	best: 9.3675751 (28)	total: 659ms	remaining: 1.61s
# 29:	learn: 5.7028240	test: 9.2847322	best: 9.2847322 (29)	total: 680ms	remaining: 1.58s
# 30:	learn: 5.6008645	test: 9.1734793	best: 9.1734793 (30)	total: 703ms	remaining: 1.56s
# 31:	learn: 5.5157655	test: 9.1038050	best: 9.1038050 (31)	total: 725ms	remaining: 1.54s
# 32:	learn: 5.3992108	test: 9.0118281	best: 9.0118281 (32)	total: 747ms	remaining: 1.51s
# 33:	learn: 5.3432400	test: 9.0049720	best: 9.0049720 (33)	total: 766ms	remaining: 1.49s
# 34:	learn: 5.2094048	test: 8.9992659	best: 8.9992659 (34)	total: 792ms	remaining: 1.47s
# 35:	learn: 5.1673213	test: 8.9509448	best: 8.9509448 (35)	total: 810ms	remaining: 1.44s
# 36:	learn: 5.0276336	test: 8.9142667	best: 8.9142667 (36)	total: 832ms	remaining: 1.42s
# 37:	learn: 4.8896116	test: 8.8358924	best: 8.8358924 (37)	total: 848ms	remaining: 1.38s
# 38:	learn: 4.7928309	test: 8.8095227	best: 8.8095227 (38)	total: 867ms	remaining: 1.35s
# 39:	learn: 4.6662828	test: 8.7628513	best: 8.7628513 (39)	total: 888ms	remaining: 1.33s
# 40:	learn: 4.5574424	test: 8.7502030	best: 8.7502030 (40)	total: 905ms	remaining: 1.3s
# 41:	learn: 4.4606468	test: 8.7015445	best: 8.7015445 (41)	total: 935ms	remaining: 1.29s
# 42:	learn: 4.3566961	test: 8.6394988	best: 8.6394988 (42)	total: 959ms	remaining: 1.27s
# 43:	learn: 4.2870643	test: 8.6156909	best: 8.6156909 (43)	total: 982ms	remaining: 1.25s
# 44:	learn: 4.2091596	test: 8.5826013	best: 8.5826013 (44)	total: 1.01s	remaining: 1.24s
# 45:	learn: 4.1544888	test: 8.5137520	best: 8.5137520 (45)	total: 1.03s	remaining: 1.21s
# 46:	learn: 4.1024943	test: 8.4862166	best: 8.4862166 (46)	total: 1.06s	remaining: 1.19s
# 47:	learn: 4.0750093	test: 8.4797191	best: 8.4797191 (47)	total: 1.08s	remaining: 1.17s
# 48:	learn: 3.9317611	test: 8.3873148	best: 8.3873148 (48)	total: 1.1s	remaining: 1.14s
# 49:	learn: 3.9192195	test: 8.3903417	best: 8.3873148 (48)	total: 1.13s	remaining: 1.13s
# 50:	learn: 3.9006498	test: 8.3876575	best: 8.3873148 (48)	total: 1.15s	remaining: 1.1s
# 51:	learn: 3.8864648	test: 8.3772996	best: 8.3772996 (51)	total: 1.16s	remaining: 1.07s
# 52:	learn: 3.8076873	test: 8.3431132	best: 8.3431132 (52)	total: 1.18s	remaining: 1.05s
# 53:	learn: 3.7913112	test: 8.3256074	best: 8.3256074 (53)	total: 1.21s	remaining: 1.03s
# 54:	learn: 3.7830057	test: 8.3084743	best: 8.3084743 (54)	total: 1.23s	remaining: 1.01s
# 55:	learn: 3.7740580	test: 8.2969334	best: 8.2969334 (55)	total: 1.25s	remaining: 983ms
# 56:	learn: 3.7082507	test: 8.2773994	best: 8.2773994 (56)	total: 1.28s	remaining: 968ms
# 57:	learn: 3.6463192	test: 8.2545445	best: 8.2545445 (57)	total: 1.31s	remaining: 950ms
# 58:	learn: 3.5721030	test: 8.1946307	best: 8.1946307 (58)	total: 1.35s	remaining: 940ms
# 59:	learn: 3.5231887	test: 8.2206275	best: 8.1946307 (58)	total: 1.37s	remaining: 915ms
# 60:	learn: 3.4502558	test: 8.2168202	best: 8.1946307 (58)	total: 1.39s	remaining: 891ms
# 61:	learn: 3.4248744	test: 8.2305919	best: 8.1946307 (58)	total: 1.42s	remaining: 873ms
# 62:	learn: 3.3911055	test: 8.2131295	best: 8.1946307 (58)	total: 1.44s	remaining: 847ms
# 63:	learn: 3.3432959	test: 8.1846629	best: 8.1846629 (63)	total: 1.47s	remaining: 825ms
# 64:	learn: 3.3113113	test: 8.1831114	best: 8.1831114 (64)	total: 1.49s	remaining: 801ms
# 65:	learn: 3.2319166	test: 8.2001932	best: 8.1831114 (64)	total: 1.51s	remaining: 781ms
# 66:	learn: 3.1978327	test: 8.1735988	best: 8.1735988 (66)	total: 1.54s	remaining: 758ms
# 67:	learn: 3.1172776	test: 8.1345146	best: 8.1345146 (67)	total: 1.56s	remaining: 735ms
# 68:	learn: 3.1111023	test: 8.1312899	best: 8.1312899 (68)	total: 1.58s	remaining: 709ms
# 69:	learn: 3.0699990	test: 8.1329372	best: 8.1312899 (68)	total: 1.61s	remaining: 692ms
# 70:	learn: 3.0637599	test: 8.1269234	best: 8.1269234 (70)	total: 1.63s	remaining: 667ms
# 71:	learn: 3.0178369	test: 8.1023991	best: 8.1023991 (71)	total: 1.66s	remaining: 646ms
# 72:	learn: 3.0135042	test: 8.0904386	best: 8.0904386 (72)	total: 1.68s	remaining: 623ms
# 73:	learn: 2.9771999	test: 8.0660697	best: 8.0660697 (73)	total: 1.71s	remaining: 601ms
# 74:	learn: 2.9351702	test: 8.0503986	best: 8.0503986 (74)	total: 1.76s	remaining: 587ms
# 75:	learn: 2.9256094	test: 8.0425482	best: 8.0425482 (75)	total: 1.79s	remaining: 565ms
# 76:	learn: 2.8779061	test: 8.0367166	best: 8.0367166 (76)	total: 1.82s	remaining: 543ms
# 77:	learn: 2.8724235	test: 8.0301765	best: 8.0301765 (77)	total: 1.84s	remaining: 519ms
# 78:	learn: 2.8489274	test: 8.0272128	best: 8.0272128 (78)	total: 1.87s	remaining: 498ms
# 79:	learn: 2.8077320	test: 8.0169163	best: 8.0169163 (79)	total: 1.9s	remaining: 474ms
# 80:	learn: 2.7717730	test: 8.0115808	best: 8.0115808 (80)	total: 1.92s	remaining: 450ms
# 81:	learn: 2.7044355	test: 7.9682647	best: 7.9682647 (81)	total: 1.93s	remaining: 424ms
# 82:	learn: 2.6765965	test: 7.9606646	best: 7.9606646 (82)	total: 1.95s	remaining: 399ms
# 83:	learn: 2.6722449	test: 7.9527369	best: 7.9527369 (83)	total: 1.96s	remaining: 374ms
# 84:	learn: 2.6500024	test: 7.9439730	best: 7.9439730 (84)	total: 1.98s	remaining: 350ms
# 85:	learn: 2.6080086	test: 7.9170931	best: 7.9170931 (85)	total: 2s	remaining: 325ms
# 86:	learn: 2.6051010	test: 7.9161510	best: 7.9161510 (86)	total: 2.02s	remaining: 302ms
# 87:	learn: 2.5522485	test: 7.9119028	best: 7.9119028 (87)	total: 2.04s	remaining: 278ms
# 88:	learn: 2.5482438	test: 7.9058993	best: 7.9058993 (88)	total: 2.06s	remaining: 254ms
# 89:	learn: 2.5099964	test: 7.8795425	best: 7.8795425 (89)	total: 2.08s	remaining: 231ms
# 90:	learn: 2.4531920	test: 7.8648501	best: 7.8648501 (90)	total: 2.1s	remaining: 207ms
# 91:	learn: 2.4413973	test: 7.8626569	best: 7.8626569 (91)	total: 2.11s	remaining: 184ms
# 92:	learn: 2.4133649	test: 7.8432500	best: 7.8432500 (92)	total: 2.13s	remaining: 160ms
# 93:	learn: 2.3800078	test: 7.8249138	best: 7.8249138 (93)	total: 2.15s	remaining: 138ms
# 94:	learn: 2.3618615	test: 7.8251215	best: 7.8249138 (93)	total: 2.18s	remaining: 115ms
# 95:	learn: 2.3583062	test: 7.8192412	best: 7.8192412 (95)	total: 2.2s	remaining: 91.8ms
# 96:	learn: 2.3546505	test: 7.8137443	best: 7.8137443 (96)	total: 2.22s	remaining: 68.7ms
# 97:	learn: 2.3516868	test: 7.8065371	best: 7.8065371 (97)	total: 2.24s	remaining: 45.7ms
# 98:	learn: 2.3196339	test: 7.7978428	best: 7.7978428 (98)	total: 2.26s	remaining: 22.8ms
# 99:	learn: 2.3092974	test: 7.7999571	best: 7.7978428 (98)	total: 2.28s	remaining: 0us
#
# bestTest = 7.797842779
# bestIteration = 98
#
# Shrink model to first 99 iterations.
# Learning rate set to 0.192782
# 0:	learn: 37.0416267	test: 36.0757651	best: 36.0757651 (0)	total: 28.4ms	remaining: 2.81s
# 1:	learn: 32.5224388	test: 31.7186857	best: 31.7186857 (1)	total: 48.8ms	remaining: 2.39s
# 2:	learn: 28.6277560	test: 28.1292660	best: 28.1292660 (2)	total: 71.4ms	remaining: 2.31s
# 3:	learn: 25.3743384	test: 24.6900565	best: 24.6900565 (3)	total: 88.8ms	remaining: 2.13s
# 4:	learn: 22.5516143	test: 21.8985257	best: 21.8985257 (4)	total: 107ms	remaining: 2.04s
# 5:	learn: 20.4058081	test: 19.9214114	best: 19.9214114 (5)	total: 128ms	remaining: 2s
# 6:	learn: 18.4816379	test: 18.6027317	best: 18.6027317 (6)	total: 150ms	remaining: 1.99s
# 7:	learn: 16.5472063	test: 17.0309586	best: 17.0309586 (7)	total: 176ms	remaining: 2.03s
# 8:	learn: 15.1913678	test: 15.7434962	best: 15.7434962 (8)	total: 197ms	remaining: 1.99s
# 9:	learn: 13.7896769	test: 14.8028021	best: 14.8028021 (9)	total: 217ms	remaining: 1.95s
# 10:	learn: 12.6683755	test: 13.6839280	best: 13.6839280 (10)	total: 242ms	remaining: 1.96s
# 11:	learn: 11.7813054	test: 13.1406638	best: 13.1406638 (11)	total: 265ms	remaining: 1.94s
# 12:	learn: 10.9164811	test: 12.3352984	best: 12.3352984 (12)	total: 284ms	remaining: 1.9s
# 13:	learn: 10.1726713	test: 11.6567321	best: 11.6567321 (13)	total: 301ms	remaining: 1.85s
# 14:	learn: 9.5707441	test: 11.3153148	best: 11.3153148 (14)	total: 318ms	remaining: 1.8s
# 15:	learn: 9.1318576	test: 10.8467736	best: 10.8467736 (15)	total: 340ms	remaining: 1.78s
# 16:	learn: 8.7423888	test: 10.4468315	best: 10.4468315 (16)	total: 368ms	remaining: 1.8s
# 17:	learn: 8.3111875	test: 10.1346148	best: 10.1346148 (17)	total: 385ms	remaining: 1.75s
# 18:	learn: 8.0800942	test: 9.9152170	best: 9.9152170 (18)	total: 403ms	remaining: 1.72s
# 19:	learn: 7.8540985	test: 9.8189797	best: 9.8189797 (19)	total: 426ms	remaining: 1.71s
# 20:	learn: 7.5644515	test: 9.6752372	best: 9.6752372 (20)	total: 463ms	remaining: 1.74s
# 21:	learn: 7.3007926	test: 9.4391572	best: 9.4391572 (21)	total: 489ms	remaining: 1.73s
# 22:	learn: 7.0844457	test: 9.2722870	best: 9.2722870 (22)	total: 514ms	remaining: 1.72s
# 23:	learn: 6.9627849	test: 9.1525667	best: 9.1525667 (23)	total: 583ms	remaining: 1.85s
# 24:	learn: 6.8160987	test: 9.0144695	best: 9.0144695 (24)	total: 607ms	remaining: 1.82s
# 25:	learn: 6.6086161	test: 8.7972534	best: 8.7972534 (25)	total: 626ms	remaining: 1.78s
# 26:	learn: 6.4573319	test: 8.6739066	best: 8.6739066 (26)	total: 647ms	remaining: 1.75s
# 27:	learn: 6.3535548	test: 8.5674275	best: 8.5674275 (27)	total: 669ms	remaining: 1.72s
# 28:	learn: 6.1768343	test: 8.4501062	best: 8.4501062 (28)	total: 688ms	remaining: 1.69s
# 29:	learn: 6.0429037	test: 8.3722342	best: 8.3722342 (29)	total: 719ms	remaining: 1.68s
# 30:	learn: 5.8799899	test: 8.3284174	best: 8.3284174 (30)	total: 750ms	remaining: 1.67s
# 31:	learn: 5.7098427	test: 8.3362018	best: 8.3284174 (30)	total: 793ms	remaining: 1.69s
# 32:	learn: 5.5852526	test: 8.2790585	best: 8.2790585 (32)	total: 815ms	remaining: 1.66s
# 33:	learn: 5.4918482	test: 8.1866202	best: 8.1866202 (33)	total: 845ms	remaining: 1.64s
# 34:	learn: 5.4115607	test: 8.1540877	best: 8.1540877 (34)	total: 867ms	remaining: 1.61s
# 35:	learn: 5.2548557	test: 8.0404538	best: 8.0404538 (35)	total: 887ms	remaining: 1.58s
# 36:	learn: 5.1765486	test: 8.0163044	best: 8.0163044 (36)	total: 911ms	remaining: 1.55s
# 37:	learn: 5.0455085	test: 7.9939333	best: 7.9939333 (37)	total: 929ms	remaining: 1.52s
# 38:	learn: 5.0219098	test: 7.9808176	best: 7.9808176 (38)	total: 950ms	remaining: 1.49s
# 39:	learn: 4.9302017	test: 7.9502877	best: 7.9502877 (39)	total: 974ms	remaining: 1.46s
# 40:	learn: 4.7664025	test: 7.8382893	best: 7.8382893 (40)	total: 992ms	remaining: 1.43s
# 41:	learn: 4.7485725	test: 7.8291528	best: 7.8291528 (41)	total: 1.01s	remaining: 1.4s
# 42:	learn: 4.6424052	test: 7.8274519	best: 7.8274519 (42)	total: 1.04s	remaining: 1.38s
# 43:	learn: 4.5474406	test: 7.7675300	best: 7.7675300 (43)	total: 1.06s	remaining: 1.35s
# 44:	learn: 4.4318176	test: 7.7162784	best: 7.7162784 (44)	total: 1.08s	remaining: 1.32s
# 45:	learn: 4.3740331	test: 7.6756943	best: 7.6756943 (45)	total: 1.1s	remaining: 1.3s
# 46:	learn: 4.2673097	test: 7.5978916	best: 7.5978916 (46)	total: 1.12s	remaining: 1.27s
# 47:	learn: 4.2450744	test: 7.6032681	best: 7.5978916 (46)	total: 1.15s	remaining: 1.24s
# 48:	learn: 4.1966594	test: 7.5808891	best: 7.5808891 (48)	total: 1.16s	remaining: 1.21s
# 49:	learn: 4.1159915	test: 7.5670827	best: 7.5670827 (49)	total: 1.18s	remaining: 1.18s
# 50:	learn: 4.1060176	test: 7.5670200	best: 7.5670200 (50)	total: 1.2s	remaining: 1.15s
# 51:	learn: 4.0873526	test: 7.5466475	best: 7.5466475 (51)	total: 1.23s	remaining: 1.13s
# 52:	learn: 4.0749769	test: 7.5391446	best: 7.5391446 (52)	total: 1.25s	remaining: 1.1s
# 53:	learn: 3.9083358	test: 7.4628435	best: 7.4628435 (53)	total: 1.27s	remaining: 1.08s
# 54:	learn: 3.8238061	test: 7.4005295	best: 7.4005295 (54)	total: 1.29s	remaining: 1.06s
# 55:	learn: 3.7636324	test: 7.3744377	best: 7.3744377 (55)	total: 1.32s	remaining: 1.03s
# 56:	learn: 3.6940231	test: 7.3530501	best: 7.3530501 (56)	total: 1.34s	remaining: 1.01s
# 57:	learn: 3.6462087	test: 7.3537277	best: 7.3530501 (56)	total: 1.36s	remaining: 988ms
# 58:	learn: 3.5800333	test: 7.3265725	best: 7.3265725 (58)	total: 1.38s	remaining: 961ms
# 59:	learn: 3.4655884	test: 7.2688333	best: 7.2688333 (59)	total: 1.4s	remaining: 937ms
# 60:	learn: 3.4078387	test: 7.2596374	best: 7.2596374 (60)	total: 1.43s	remaining: 916ms
# 61:	learn: 3.3980877	test: 7.2639402	best: 7.2596374 (60)	total: 1.45s	remaining: 891ms
# 62:	learn: 3.3489134	test: 7.2303390	best: 7.2303390 (62)	total: 1.48s	remaining: 870ms
# 63:	learn: 3.2438741	test: 7.2403040	best: 7.2303390 (62)	total: 1.5s	remaining: 846ms
# 64:	learn: 3.2276578	test: 7.2373916	best: 7.2303390 (62)	total: 1.52s	remaining: 821ms
# 65:	learn: 3.1358730	test: 7.2057143	best: 7.2057143 (65)	total: 1.55s	remaining: 799ms
# 66:	learn: 3.0558951	test: 7.1474713	best: 7.1474713 (66)	total: 1.58s	remaining: 778ms
# 67:	learn: 3.0336666	test: 7.1317276	best: 7.1317276 (67)	total: 1.6s	remaining: 752ms
# 68:	learn: 2.9757581	test: 7.1272522	best: 7.1272522 (68)	total: 1.63s	remaining: 732ms
# 69:	learn: 2.9633069	test: 7.1095015	best: 7.1095015 (69)	total: 1.65s	remaining: 706ms
# 70:	learn: 2.9118471	test: 7.0915451	best: 7.0915451 (70)	total: 1.67s	remaining: 682ms
# 71:	learn: 2.9040247	test: 7.0816048	best: 7.0816048 (71)	total: 1.72s	remaining: 668ms
# 72:	learn: 2.8546519	test: 7.0787730	best: 7.0787730 (72)	total: 1.74s	remaining: 642ms
# 73:	learn: 2.8513179	test: 7.0809892	best: 7.0787730 (72)	total: 1.77s	remaining: 622ms
# 74:	learn: 2.7923525	test: 7.0638754	best: 7.0638754 (74)	total: 1.79s	remaining: 598ms
# 75:	learn: 2.7697838	test: 7.0652589	best: 7.0638754 (74)	total: 1.83s	remaining: 578ms
# 76:	learn: 2.7248362	test: 7.0618721	best: 7.0618721 (76)	total: 1.86s	remaining: 554ms
# 77:	learn: 2.7218095	test: 7.0588096	best: 7.0588096 (77)	total: 1.87s	remaining: 529ms
# 78:	learn: 2.7143423	test: 7.0583259	best: 7.0583259 (78)	total: 1.9s	remaining: 505ms
# 79:	learn: 2.6760559	test: 7.0562566	best: 7.0562566 (79)	total: 1.92s	remaining: 481ms
# 80:	learn: 2.6360811	test: 7.0300136	best: 7.0300136 (80)	total: 1.95s	remaining: 458ms
# 81:	learn: 2.6306741	test: 7.0312331	best: 7.0300136 (80)	total: 1.98s	remaining: 434ms
# 82:	learn: 2.5707634	test: 6.9951991	best: 6.9951991 (82)	total: 2.01s	remaining: 413ms
# 83:	learn: 2.5294183	test: 6.9727763	best: 6.9727763 (83)	total: 2.04s	remaining: 389ms
# 84:	learn: 2.4971866	test: 6.9677577	best: 6.9677577 (84)	total: 2.06s	remaining: 364ms
# 85:	learn: 2.4906182	test: 6.9619706	best: 6.9619706 (85)	total: 2.09s	remaining: 340ms
# 86:	learn: 2.4648135	test: 6.9458292	best: 6.9458292 (86)	total: 2.11s	remaining: 315ms
# 87:	learn: 2.4165896	test: 6.9482160	best: 6.9458292 (86)	total: 2.13s	remaining: 290ms
# 88:	learn: 2.3888004	test: 6.9326639	best: 6.9326639 (88)	total: 2.15s	remaining: 265ms
# 89:	learn: 2.3549706	test: 6.9178471	best: 6.9178471 (89)	total: 2.17s	remaining: 241ms
# 90:	learn: 2.3339162	test: 6.9115967	best: 6.9115967 (90)	total: 2.19s	remaining: 217ms
# 91:	learn: 2.3274311	test: 6.9121911	best: 6.9115967 (90)	total: 2.21s	remaining: 192ms
# 92:	learn: 2.2848177	test: 6.8758382	best: 6.8758382 (92)	total: 2.23s	remaining: 168ms
# 93:	learn: 2.2639654	test: 6.8764299	best: 6.8758382 (92)	total: 2.25s	remaining: 144ms
# 94:	learn: 2.2497011	test: 6.8734796	best: 6.8734796 (94)	total: 2.28s	remaining: 120ms
# 95:	learn: 2.2475441	test: 6.8752180	best: 6.8734796 (94)	total: 2.3s	remaining: 95.8ms
# 96:	learn: 2.2103841	test: 6.8603084	best: 6.8603084 (96)	total: 2.32s	remaining: 71.7ms
# 97:	learn: 2.1625346	test: 6.8640872	best: 6.8603084 (96)	total: 2.35s	remaining: 47.9ms
# 98:	learn: 2.1430102	test: 6.8463012	best: 6.8463012 (98)	total: 2.37s	remaining: 23.9ms
# 99:	learn: 2.1239115	test: 6.8434294	best: 6.8434294 (99)	total: 2.39s	remaining: 0us
#
# bestTest = 6.843429358
# bestIteration = 99
#
# Learning rate set to 0.19283
# 0:	learn: 36.9797226	test: 33.3546598	best: 33.3546598 (0)	total: 39.1ms	remaining: 3.87s
# 1:	learn: 32.0837481	test: 29.5388560	best: 29.5388560 (1)	total: 61.2ms	remaining: 3s
# 2:	learn: 28.0803104	test: 26.3738077	best: 26.3738077 (2)	total: 90.8ms	remaining: 2.94s
# 3:	learn: 24.7476860	test: 23.5690412	best: 23.5690412 (3)	total: 112ms	remaining: 2.68s
# 4:	learn: 21.7188604	test: 21.1679201	best: 21.1679201 (4)	total: 135ms	remaining: 2.57s
# 5:	learn: 19.6560902	test: 19.3653973	best: 19.3653973 (5)	total: 162ms	remaining: 2.53s
# 6:	learn: 17.7374135	test: 18.2963908	best: 18.2963908 (6)	total: 184ms	remaining: 2.44s
# 7:	learn: 15.9684508	test: 16.7608625	best: 16.7608625 (7)	total: 212ms	remaining: 2.44s
# 8:	learn: 14.6938277	test: 15.8974599	best: 15.8974599 (8)	total: 234ms	remaining: 2.37s
# 9:	learn: 13.2971526	test: 14.8170184	best: 14.8170184 (9)	total: 251ms	remaining: 2.26s
# 10:	learn: 12.3410845	test: 14.1179785	best: 14.1179785 (10)	total: 276ms	remaining: 2.23s
# 11:	learn: 11.4665506	test: 13.5474183	best: 13.5474183 (11)	total: 295ms	remaining: 2.16s
# 12:	learn: 10.6565411	test: 13.0436517	best: 13.0436517 (12)	total: 314ms	remaining: 2.1s
# 13:	learn: 9.9174391	test: 12.5178095	best: 12.5178095 (13)	total: 331ms	remaining: 2.03s
# 14:	learn: 9.2438369	test: 11.9322911	best: 11.9322911 (14)	total: 354ms	remaining: 2s
# 15:	learn: 8.6917461	test: 11.5708824	best: 11.5708824 (15)	total: 374ms	remaining: 1.96s
# 16:	learn: 8.2734122	test: 11.3077552	best: 11.3077552 (16)	total: 405ms	remaining: 1.98s
# 17:	learn: 7.8373804	test: 11.1256908	best: 11.1256908 (17)	total: 427ms	remaining: 1.95s
# 18:	learn: 7.5525528	test: 10.9742346	best: 10.9742346 (18)	total: 450ms	remaining: 1.92s
# 19:	learn: 7.2707376	test: 10.7934538	best: 10.7934538 (19)	total: 480ms	remaining: 1.92s
# 20:	learn: 7.0218176	test: 10.5820275	best: 10.5820275 (20)	total: 498ms	remaining: 1.87s
# 21:	learn: 6.7730499	test: 10.4326501	best: 10.4326501 (21)	total: 517ms	remaining: 1.83s
# 22:	learn: 6.5887684	test: 10.2510231	best: 10.2510231 (22)	total: 534ms	remaining: 1.79s
# 23:	learn: 6.4796136	test: 10.1843898	best: 10.1843898 (23)	total: 557ms	remaining: 1.76s
# 24:	learn: 6.3467354	test: 10.1478918	best: 10.1478918 (24)	total: 583ms	remaining: 1.75s
# 25:	learn: 6.2039071	test: 10.1034781	best: 10.1034781 (25)	total: 604ms	remaining: 1.72s
# 26:	learn: 6.0800413	test: 10.0403746	best: 10.0403746 (26)	total: 635ms	remaining: 1.72s
# 27:	learn: 5.9430699	test: 9.9858490	best: 9.9858490 (27)	total: 659ms	remaining: 1.69s
# 28:	learn: 5.7179660	test: 9.8481928	best: 9.8481928 (28)	total: 674ms	remaining: 1.65s
# 29:	learn: 5.6186440	test: 9.8072993	best: 9.8072993 (29)	total: 703ms	remaining: 1.64s
# 30:	learn: 5.5362877	test: 9.8143969	best: 9.8072993 (29)	total: 726ms	remaining: 1.61s
# 31:	learn: 5.4172860	test: 9.7746518	best: 9.7746518 (31)	total: 754ms	remaining: 1.6s
# 32:	learn: 5.3243806	test: 9.7005555	best: 9.7005555 (32)	total: 776ms	remaining: 1.57s
# 33:	learn: 5.2582022	test: 9.6543466	best: 9.6543466 (33)	total: 800ms	remaining: 1.55s
# 34:	learn: 5.1344334	test: 9.6040140	best: 9.6040140 (34)	total: 826ms	remaining: 1.53s
# 35:	learn: 5.1146082	test: 9.5976657	best: 9.5976657 (35)	total: 844ms	remaining: 1.5s
# 36:	learn: 5.0345319	test: 9.5663615	best: 9.5663615 (36)	total: 861ms	remaining: 1.47s
# 37:	learn: 4.9584768	test: 9.5560866	best: 9.5560866 (37)	total: 878ms	remaining: 1.43s
# 38:	learn: 4.8290183	test: 9.4709709	best: 9.4709709 (38)	total: 905ms	remaining: 1.42s
# 39:	learn: 4.7774964	test: 9.4300775	best: 9.4300775 (39)	total: 923ms	remaining: 1.38s
# 40:	learn: 4.7617893	test: 9.4359562	best: 9.4300775 (39)	total: 940ms	remaining: 1.35s
# 41:	learn: 4.7424738	test: 9.4309895	best: 9.4300775 (39)	total: 964ms	remaining: 1.33s
# 42:	learn: 4.6238980	test: 9.3753620	best: 9.3753620 (42)	total: 987ms	remaining: 1.31s
# 43:	learn: 4.5986060	test: 9.3679023	best: 9.3679023 (43)	total: 1.01s	remaining: 1.28s
# 44:	learn: 4.5122887	test: 9.2892953	best: 9.2892953 (44)	total: 1.05s	remaining: 1.28s
# 45:	learn: 4.4966477	test: 9.2940716	best: 9.2892953 (44)	total: 1.08s	remaining: 1.27s
# 46:	learn: 4.4078051	test: 9.2642545	best: 9.2642545 (46)	total: 1.13s	remaining: 1.27s
# 47:	learn: 4.2897834	test: 9.1541425	best: 9.1541425 (47)	total: 1.16s	remaining: 1.25s
# 48:	learn: 4.1888139	test: 9.0848485	best: 9.0848485 (48)	total: 1.18s	remaining: 1.23s
# 49:	learn: 4.1119029	test: 9.0419159	best: 9.0419159 (49)	total: 1.2s	remaining: 1.2s
# 50:	learn: 4.0970785	test: 9.0429426	best: 9.0419159 (49)	total: 1.23s	remaining: 1.18s
# 51:	learn: 4.0230052	test: 9.0480223	best: 9.0419159 (49)	total: 1.25s	remaining: 1.15s
# 52:	learn: 3.9779768	test: 9.0395607	best: 9.0395607 (52)	total: 1.27s	remaining: 1.13s
# 53:	learn: 3.9648093	test: 9.0399398	best: 9.0395607 (52)	total: 1.29s	remaining: 1.1s
# 54:	learn: 3.8569059	test: 9.0038764	best: 9.0038764 (54)	total: 1.31s	remaining: 1.07s
# 55:	learn: 3.8286348	test: 9.0165737	best: 9.0038764 (54)	total: 1.33s	remaining: 1.04s
# 56:	learn: 3.8183225	test: 9.0248147	best: 9.0038764 (54)	total: 1.34s	remaining: 1.01s
# 57:	learn: 3.7798346	test: 8.9738504	best: 8.9738504 (57)	total: 1.37s	remaining: 989ms
# 58:	learn: 3.7047403	test: 8.9261782	best: 8.9261782 (58)	total: 1.39s	remaining: 963ms
# 59:	learn: 3.6658287	test: 8.9123874	best: 8.9123874 (59)	total: 1.41s	remaining: 939ms
# 60:	learn: 3.5871208	test: 8.8789081	best: 8.8789081 (60)	total: 1.45s	remaining: 925ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6530/28049388.py in <cell line: 8>()
#      11
#      12     model = CatBoostRegressor(iterations=100,metric_period=1,verbose=1,random_state=42)
# ---> 13     model.fit(
#      14         X_train,
#      15         y_train,
#
# ~/.conda/envs/default/lib/python3.9/site-packages/catboost/core.py in fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5728             CatBoostRegressor._check_is_compatible_loss(params['loss_function'])
#    5729
# -> 5730         return self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline,
#    5731                          use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description,
#    5732                          verbose_eval, metric_period, silent, early_stopping_rounds,
#
# ~/.conda/envs/default/lib/python3.9/site-packages/catboost/core.py in _fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2353         with log_fixup(log_cout, log_cerr), \
#    2354             plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(self.get_params())]):
# -> 2355             self._train(
#    2356                 train_pool,
#    2357                 train_params["eval_sets"],
#
# ~/.conda/envs/default/lib/python3.9/site-packages/catboost/core.py in _train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1757
#    1758     def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1759         self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1760         self._set_trained_model_attributes()
#    1761
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import mean_squared_error

tr_pred = np.mean(tr_preds,axis=0)
va_pred = np.mean(va_preds,axis=0)
te_pred = np.mean(te_preds,axis=0)

tr_score = np.sqrt(mean_squared_error(y_pred=tr_pred,y_true=y_train))
va_score = np.sqrt(mean_squared_error(y_pred=va_pred,y_true=y_valid))
print(tr_score,va_score)

# %%
i = 0
for case_num in ['01','02','03','04','05']:
    test_case_df = pd.read_csv(f'./data/test_target/TEST_{case_num}.csv')
    test_case_df['predicted_weight_g'] = te_pred[(i*28):(i*28+28)]
    test_case_df.to_csv(f'./data/test_target/TEST_{case_num}.csv',index=False)
    i+=1

# %%
import zipfile

test_target_list = sorted(glob.glob('/home/studio-lab-user/Dacon/6_상추생육환경생성/data/test_target/*.csv'))

os.chdir("./data/test_target/")
submission = zipfile.ZipFile("../submission.zip", 'w')
for path in test_target_list:
    path = path.split('/')[-1]
    submission.write(path)
submission.close()
